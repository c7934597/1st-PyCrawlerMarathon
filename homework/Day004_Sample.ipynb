# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"10974200864","type":"PushEvent","actor":{"id":15169396,"login":"AnyLifeZLB","display_login":"AnyLifeZLB","gravatar_id":"","url":"https://api.github.com/users/AnyLifeZLB","avatar_url":"https://avatars.githubusercontent.com/u/15169396?"},"repo":{"id":150832834,"name":"AnyLifeZLB/MVP-Dagger2-Rxjava2","url":"https://api.github.com/repos/AnyLifeZLB/MVP-Dagger2-Rxjava2"},"payload":{"push_id":4334899920,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"e611f720928bfa42aacc5770c1f16d7dd97b00e8","before":"3c9db192dc8102b57dc7e951bdc4d2f4f575d6a9","commits":[{"sha":"e611f720928bfa42aacc5770c1f16d7dd97b00e8","author":{"email":"zenglb@vanke.com","name":"曾刘保.Felix"},"message":"更新ReadMe","distinct":true,"url":"https://api.github.com/repos/AnyLifeZLB/MVP-Dagger2-Rxjava2/commits/e611f720928bfa42aacc5770c1f16d7dd97b00e8"}]},"public":true,"created_at":"2019-11-29T08:32:01Z"},{"id":"10974200862","type":"PushEvent","actor":{"id":11502547,"login":"pikl-cz","display_login":"pikl-cz","gravatar_id":"","url":"https://api.github.com/users/pikl-cz","avatar_url":"https://avatars.githubusercontent.com/u/11502547?"},"repo":{"id":203565572,"name":"pikl-cz/vuejs","url":"https://api.github.com/repos/pikl-cz/vuejs"},"payload":{"push_id":4334899925,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"a8eaafd624e3d3fa1f745b1144e4c185c5d4dc8b","before":"a710d0dbc7cc93f61740df127fd2b544304ea9bf","commits":[{"sha":"a8eaafd624e3d3fa1f745b1144e4c185c5d4dc8b","author":{"email":"jan.pikl@cninvest.cz","name":"Jan Pikl"},"message":"last lecture 42","distinct":true,"url":"https://api.github.com/repos/pikl-cz/vuejs/commits/a8eaafd624e3d3fa1f745b1144e4c185c5d4dc8b"}]},"public":true,"created_at":"2019-11-29T08:32:01Z"},{"id":"10974200865","type":"IssuesEvent","actor":{"id":31465531,"login":"timjamwoo","display_login":"timjamwoo","gravatar_id":"","url":"https://api.github.com/users/timjamwoo","avatar_url":"https://avatars.githubusercontent.com/u/31465531?"},"repo":{"id":221888181,"name":"quoteforce/QuestionBuilder","url":"https://api.github.com/repos/quoteforce/QuestionBuilder"},"payload":{"action":"opened","issue":{"url":"https://api.github.com/repos/quoteforce/QuestionBuilder/issues/37","repository_url":"https://api.github.com/repos/quoteforce/QuestionBuilder","labels_url":"https://api.github.com/repos/quoteforce/QuestionBuilder/issues/37/labels{/name}","comments_url":"https://api.github.com/repos/quoteforce/QuestionBuilder/issues/37/comments","events_url":"https://api.github.com/repos/quoteforce/QuestionBuilder/issues/37/events","html_url":"https://github.com/quoteforce/QuestionBuilder/issues/37","id":530217858,"node_id":"MDU6SXNzdWU1MzAyMTc4NTg=","number":37,"title":"Improve code quality","user":{"login":"timjamwoo","id":31465531,"node_id":"MDQ6VXNlcjMxNDY1NTMx","avatar_url":"https://avatars1.githubusercontent.com/u/31465531?v=4","gravatar_id":"","url":"https://api.github.com/users/timjamwoo","html_url":"https://github.com/timjamwoo","followers_url":"https://api.github.com/users/timjamwoo/followers","following_url":"https://api.github.com/users/timjamwoo/following{/other_user}","gists_url":"https://api.github.com/users/timjamwoo/gists{/gist_id}","starred_url":"https://api.github.com/users/timjamwoo/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/timjamwoo/subscriptions","organizations_url":"https://api.github.com/users/timjamwoo/orgs","repos_url":"https://api.github.com/users/timjamwoo/repos","events_url":"https://api.github.com/users/timjamwoo/events{/privacy}","received_events_url":"https://api.github.com/users/timjamwoo/received_events","type":"User","site_admin":false},"labels":[],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":0,"created_at":"2019-11-29T08:32:01Z","updated_at":"2019-11-29T08:32:01Z","closed_at":null,"author_association":"CONTRIBUTOR","body":""}},"public":true,"created_at":"2019-11-29T08:32:01Z","org":{"id":57659907,"login":"quoteforce","gravatar_id":"","url ...

# %%
import json

json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.19.1'},
#  'origin': '1.172.176.99, 1.172.176.99',
#  'url': 'https://httpbin.org/get?key1=value1&key2=value2'}

# %% [markdown]
# ## 其它用法

# %% [markdown]
# get後面加查詢參數，參數會被加到網址後面

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.19.1'},
#  'origin': '1.172.176.99, 1.172.176.99',
#  'url': 'https://httpbin.org/get?key1=value1&key2=value2'}

# %%
r.url
# Out:
# 'http://httpbin.org/get?key1=value1&key2=value2'

# %% [markdown]
# post後面加參數，就是要傳進去FORM的資料

# %%
r = requests.post('http://httpbin.org/post')
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '0',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.19.1'},
#  'json': None,
#  'origin': '1.172.176.99, 1.172.176.99',
#  'url': 'https://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.19.1'},
#  'json': None,
#  'origin': '1.172.176.99, 1.172.176.99',
#  'url': 'https://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
